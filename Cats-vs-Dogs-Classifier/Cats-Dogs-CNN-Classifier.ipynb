# %% [markdown]
# ## Importing necessary libraries

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import random
import os

import warnings
warnings.simplefilter('ignore')

# %%
# importing libraries for deep learning
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# %% [markdown]
# ## Reading the datafiles

# %%
# specifying dataset directories
train_dir = "/kaggle/input/dogs-vs-cats/train/train"
test_dir = "/kaggle/input/dogs-vs-cats/test/test"

print('number of training images - ',len(os.listdir(train_dir)))
print('number of testing images - ',len(os.listdir(test_dir)))
# Out:
# number of training images -  25000
# number of testing images -  12500

# %% [markdown]
# ## Creating Training & Testing Data

# %%
IMG_SIZE = 60

CATEGORIES = ["cat", "dog"]

# %%
CATEGORIES.index("cat")
# Out:
# 0

# %%
# creating training dataset
def create_training_data():
    training_data  = []
    images = []
    labels = []
    
    imagefiles = [os.path.join(train_dir,f) for f in os.listdir(train_dir)]
    for image in imagefiles:
        category = image.split('/')[-1].split('.')[0]
        img_array = cv2.imread(image, cv2.IMREAD_GRAYSCALE)
        new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
        training_data .append([new_array, CATEGORIES.index(category)])
        
    random.shuffle(training_data)
    for features,label in training_data:
        images.append(features)
        labels.append(label)
    images = np.array(images).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
    
    return images, labels

# %%
images, labels = create_training_data()

# %%
len(images)
# Out:
# 25000

# %%
# creating testing data
def create_testing_data():
    test_images  = []
    
    imagefiles = [os.path.join(test_dir,f) for f in os.listdir(test_dir)]
    for image in imagefiles:
        img_array = cv2.imread(image, cv2.IMREAD_GRAYSCALE)
        new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
        test_images .append(new_array)
        
    random.shuffle(test_images)
#     test_images = np.array(test_images).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
    return test_images


test_images = create_testing_data()
len(test_images)
# Out:
# 12500

# %%
len(test_images[0])
# Out:
# 60

# %%
# standardizing between 0 to 255
X_train = images / 255.0
X_test = np.array(test_images).reshape(-1, IMG_SIZE, IMG_SIZE, 1) / 255.0

y_train = np.array(labels)

# convert from int to float
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %% [markdown]
# ## Model Building

# %%
input_shape = (IMG_SIZE, IMG_SIZE, 1)

batch_size = 32
num_classes = 2
epochs = 100

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3,3), activation="relu", input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(rate=0.15))

model.add(Conv2D(filters=64, kernel_size=(3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(rate=0.2))

model.add(Conv2D(filters=128, kernel_size=(3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(rate=0.3))
model.add(Flatten())

model.add(Dense(units=32, activation="relu"))
model.add(Dropout(rate=0.1))

model.add(Dense(units=num_classes, activation="softmax"))

# %% [markdown]
# ## Compiling the model

# %%
# ? model.compile

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 58, 58, 32)        320
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 29, 29, 32)        0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 29, 29, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 27, 27, 64)        18496
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 11, 11, 128)       73856
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                102432
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 195,170
# Trainable params: 195,170
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fitting the model

# %%
# ? model.fit

# %%
history = model.fit(X_train, y_train,
                    batch_size = batch_size,
                    steps_per_epoch = 1000,
                    epochs = epochs,
                    validation_split = 0.2,
                    validation_steps = 1000)
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6184 - accuracy: 0.6477 - val_loss: 0.5319 - val_accuracy: 0.7336
# Epoch 2/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5217 - accuracy: 0.7414 - val_loss: 0.4612 - val_accuracy: 0.7848
# Epoch 3/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.4584 - accuracy: 0.7827 - val_loss: 0.4398 - val_accuracy: 0.7878
# Epoch 4/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4108 - accuracy: 0.8144 - val_loss: 0.3908 - val_accuracy: 0.8232
# Epoch 5/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.3740 - accuracy: 0.8300 - val_loss: 0.3663 - val_accuracy: 0.8390
# Epoch 6/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.3427 - accuracy: 0.8487 - val_loss: 0.3528 - val_accuracy: 0.8420
# Epoch 7/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.3247 - accuracy: 0.8565 - val_loss: 0.3497 - val_accuracy: 0.8434
# Epoch 8/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2993 - accuracy: 0.8699 - val_loss: 0.3428 - val_accuracy: 0.8476
# Epoch 9/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2837 - accuracy: 0.8767 - val_loss: 0.3369 - val_accuracy: 0.8512
# Epoch 10/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2683 - accuracy: 0.8844 - val_loss: 0.3494 - val_accuracy: 0.8528
# Epoch 11/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2486 - accuracy: 0.8957 - val_loss: 0.3631 - val_accuracy: 0.8458
# Epoch 12/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.2402 - accuracy: 0.8988 - val_loss: 0.3290 - val_accuracy: 0.8584
# Epoch 13/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.2280 - accuracy: 0.9035 - val_loss: 0.3521 - val_accuracy: 0.8592
# Epoch 14/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.2124 - accuracy: 0.9104 - val_loss: 0.3561 - val_accuracy: 0.8554
# Epoch 15/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2083 - accuracy: 0.9132 - val_loss: 0.3484 - val_accuracy: 0.8670
# Epoch 16/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1969 - accuracy: 0.9177 - val_loss: 0.3734 - val_accuracy: 0.8594
# Epoch 17/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1931 - accuracy: 0.9197 - val_loss: 0.3452 - val_accuracy: 0.8632
# Epoch 18/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1832 - accuracy: 0.9250 - val_loss: 0.3711 - val_accuracy: 0.8600
# Epoch 19/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1790 - accuracy: 0.9258 - val_loss: 0.3566 - val_accuracy: 0.8624
# Epoch 20/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1752 - accuracy: 0.9276 - val_loss: 0.3606 - val_accuracy: 0.8628
# Epoch 21/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1665 - accuracy: 0.9334 - val_loss: 0.3654 - val_accuracy: 0.8682
# Epoch 22/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1657 - accuracy: 0.9333 - val_loss: 0.3841 - val_accuracy: 0.8624
# Epoch 23/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1542 - accuracy: 0.9376 - val_loss: 0.3562 - val_accuracy: 0.8696
# Epoch 24/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1533 - accuracy: 0.9389 - val_loss: 0.3632 - val_accuracy: 0.8612
# Epoch 25/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1536 - accuracy: 0.9390 - val_loss: 0.3588 - val_accuracy: 0.8656
# Epoch 26/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1467 - accuracy: 0.9410 - val_loss: 0.3743 - val_accuracy: 0.8640
# Epoch 27/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1435 - accuracy: 0.9425 - val_loss: 0.3697 - val_accuracy: 0.8684
# Epoch 28/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1407 - accuracy: 0.9430 - val_loss: 0.4084 - val_accuracy: 0.8620
# Epoch 29/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1369 - accuracy: 0.9469 - val_loss: 0.4407 - val_accuracy: 0.8542
# Epoch 30/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1335 - accuracy: 0.9459 - val_loss: 0.3643 - val_accuracy: 0.8656
# Epoch 31/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1256 - accuracy: 0.9494 - val_loss: 0.4098 - val_accuracy: 0.8662
# Epoch 32/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1326 - accuracy: 0.9480 - val_loss: 0.3822 - val_accuracy: 0.8620
# Epoch 33/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1222 - accuracy: 0.9527 - val_loss: 0.3717 - val_accuracy: 0.8704
# Epoch 34/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1215 - accuracy: 0.9503 - val_loss: 0.4000 - val_accuracy: 0.8634
# Epoch 35/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1208 - accuracy: 0.9530 - val_loss: 0.3607 - val_accuracy: 0.8706
# Epoch 36/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1177 - accuracy: 0.9537 - val_loss: 0.4162 - val_accuracy: 0.8622
# Epoch 37/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1217 - accuracy: 0.9516 - val_loss: 0.3588 - val_accuracy: 0.8630
# Epoch 38/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1156 - accuracy: 0.9549 - val_loss: 0.3919 - val_accuracy: 0.8654
# Epoch 39/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1137 - accuracy: 0.9555 - val_loss: 0.4578 - val_accuracy: 0.8618
# Epoch 40/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1106 - accuracy: 0.9573 - val_loss: 0.3539 - val_accuracy: 0.8706
# Epoch 41/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1087 - accuracy: 0.9576 - val_loss: 0.3805 - val_accuracy: 0.8712
# Epoch 42/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1066 - accuracy: 0.9588 - val_loss: 0.3911 - val_accuracy: 0.8632
# Epoch 43/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1032 - accuracy: 0.9610 - val_loss: 0.3980 - val_accuracy: 0.8664
# Epoch 44/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1057 - accuracy: 0.9592 - val_loss: 0.3727 - val_accuracy: 0.8724
# Epoch 45/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1078 - accuracy: 0.9582 - val_loss: 0.3866 - val_accuracy: 0.8692
# Epoch 46/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0998 - accuracy: 0.9623 - val_loss: 0.4015 - val_accuracy: 0.8686
# Epoch 47/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1038 - accuracy: 0.9603 - val_loss: 0.3981 - val_accuracy: 0.8666
# Epoch 48/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0971 - accuracy: 0.9616 - val_loss: 0.4124 - val_accuracy: 0.8664
# Epoch 49/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.0989 - accuracy: 0.9614 - val_loss: 0.4081 - val_accuracy: 0.8716
# Epoch 50/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1000 - accuracy: 0.9614 - val_loss: 0.3649 - val_accuracy: 0.8712
# Epoch 51/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.0970 - accuracy: 0.9633 - val_loss: 0.3727 - val_accuracy: 0.8714
# Epoch 52/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.0925 - accuracy: 0.9646 - val_loss: 0.4151 - val_accuracy: 0.8688
# Epoch 53/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.0918 - accuracy: 0.9646 - val_loss: 0.3955 - val_accuracy: 0.8628
# Epoch 54/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0900 - accuracy: 0.9659 - val_loss: 0.4517 - val_accuracy: 0.8614
# Epoch 55/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.0945 - accuracy: 0.9649 - val_loss: 0.3991 - val_accuracy: 0.8684
# Epoch 56/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0865 - accuracy: 0.9680 - val_loss: 0.3843 - val_accuracy: 0.8718
# Epoch 57/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0876 - accuracy: 0.9661 - val_loss: 0.4267 - val_accuracy: 0.8724
# Epoch 58/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0927 - accuracy: 0.9658 - val_loss: 0.4437 - val_accuracy: 0.8664
# Epoch 59/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0862 - accuracy: 0.9669 - val_loss: 0.4104 - val_accuracy: 0.8748
# Epoch 60/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0879 - accuracy: 0.9666 - val_loss: 0.4022 - val_accuracy: 0.8712
# Epoch 61/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.0861 - accuracy: 0.9681 - val_loss: 0.3746 - val_accuracy: 0.8672
# Epoch 62/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.0833 - accuracy: 0.9688 - val_loss: 0.4218 - val_accuracy: 0.8710
# Epoch 63/100
#  500/1000 [==============>...............] - 4s 7ms/step - loss: 0.0895 - accuracy: 0.9659 - val_loss: 0.4022 - val_accuracy: 0.8728

# %% [markdown]
# Let us plot the Training Accuracy vs Loss to get a better understanding of the model training.

# %%
plt.figure(figsize=(10, 10))

plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Training - Loss Function')

plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Train - Accuracy')
# Out:
# Text(0.5, 1.0, 'Train - Accuracy')

# %% [markdown]
# ## Result

# %%
#Get the predictions for the test data
predicted_classes = model.predict_classes(X_test)

# %%
predicted_classes[0]
# Out:
# 1

# %%
#Let's Visualize some predicted images 
plt.figure(figsize=(10,10))
rand = np.random.randint(0,1000*2,25)
for i in range(len(rand)):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(test_images[rand[i]], cmap="gray")
    plt.xlabel(CATEGORIES[predicted_classes[rand[i]]])

# %% [markdown]
# ## Saving the model

# %%
model.save("cnn_classifier")

# %%
loaded_model = keras.models.load_model("cnn_classifier")

# %%
np.testing.assert_allclose(
    model.predict(X_test), loaded_model.predict(X_test)
)

# %%
loaded_predicted_classes = loaded_model.predict_classes(X_test)

# %%
#Let's Visualize some predicted images 
plt.figure(figsize=(10,10))
rand = np.random.randint(0,1000*2,25)
for i in range(len(rand)):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(test_images[rand[i]], cmap="gray")
    plt.xlabel(CATEGORIES[loaded_predicted_classes[rand[i]]])
